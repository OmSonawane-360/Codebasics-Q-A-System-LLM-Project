# %%
# !pip install langchain==0.0.284 python-dotenv==1.0.0 streamlit==1.22.0 tiktoken==0.7.0 faiss-cpu==1.8.0 protobuf==3.20.3

# %%
# !pip install google-generativeai
# Out:
# ...
#   Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.22.0 requires protobuf<4,>=3.12, but you have protobuf 4.25.8 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# ...

# %%
# !pip install --upgrade langchain
# Out:
# ...
#   Using cached langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached langsmith-0.4.25-py3-none-any.whl.metadata (14 kB)
# ...
# Using cached langchain-0.3.27-py3-none-any.whl (1.0 MB)
# Using cached langsmith-0.4.25-py3-none-any.whl (379 kB)
# ...
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.0.92
#     Uninstalling langsmith-0.0.92:
#       Successfully uninstalled langsmith-0.0.92
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.0.284
#     Uninstalling langchain-0.0.284:
#       Successfully uninstalled langchain-0.0.284
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.0.38 requires langchain-core<0.2.0,>=0.1.52, but you have langchain-core 0.3.75 which is incompatible.
# ...

# %%
# !pip install langchain-google-genai
# Out:
# ...
#   Using cached langchain_core-0.1.53-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# ...
# Using cached langchain_core-0.1.53-py3-none-any.whl (303 kB)
# Using cached langsmith-0.1.147-py3-none-any.whl (311 kB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# ...
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.4.25
#     Uninstalling langsmith-0.4.25:
#       Successfully uninstalled langsmith-0.4.25
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.75
#     Uninstalling langchain-core-0.3.75:
#       Successfully uninstalled langchain-core-0.3.75
# ...

# %%
pip uninstall pydantic -y
pip install "pydantic<2"
# Out:
#   File "/tmp/ipython-input-2565707522.py", line 1
#     pip uninstall pydantic -y
#         ^
# SyntaxError: invalid syntax

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

# os.environ["GOOGLE_API_KEY"] = "AIzaSyDXXHGqbu35n2qKhPolM-rSNYZOc57e0W4"
os.environ["GOOGLE_API_KEY"] = "AIzaSyDXXHGqbu35n2qKhPolM-rSNYZOc57e0W4"

# The model "gemini-pro" is not available for the current API version.
# You can use a supported model like "gemini-1.5-flash-latest" or "gemini-1.5-pro-latest".
# As suggested in the error message, you can call ListModels to see the list of available models and their supported methods.
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash-latest", temperature=0.7)

response = llm.invoke("Write a 4-line poem about my love for coding.")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# PydanticUserError                         Traceback (most recent call last)
# /tmp/ipython-input-2313213640.py in <cell line: 0>()
#       1 import os
# ----> 2 from langchain_google_genai import ChatGoogleGenerativeAI
#       3
#       4 # os.environ["GOOGLE_API_KEY"] = "AIzaSyDXXHGqbu35n2qKhPolM-rSNYZOc57e0W4"
#       5 os.environ["GOOGLE_API_KEY"] = "AIzaSyDXXHGqbu35n2qKhPolM-rSNYZOc57e0W4"
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/__init__.py in <module>
#      55 ```
#      56 """  # noqa: E501
# ---> 57 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#      58 from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
#      59 from langchain_google_genai.llms import GoogleGenerativeAI
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in <module>
#     410
#     411
# ...

# %%
from langchain.document_loaders.csv_loader import CSVLoader

loader = CSVLoader(file_path='/codebasics_faqs.csv',source_column='prompt', encoding="latin-1")
data = loader.load()

# %%
data

# %%
# !pip install InstructorEmbedding sentence-transformers

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings
from langchain.vectorstores import FAISS

instructor_embeddings = HuggingFaceInstructEmbeddings()

vectordb = FAISS.from_documents(documents=data, embedding=instructor_embeddings)

# %%
retriever = vectordb.as_retriever()
rdocs = retriever.get_relevant_documents("for how long is this course valid ?")
rdocs

# %%
# !pip install --upgrade langchain

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import RetrievalQA


llm = ChatGoogleGenerativeAI(model="gemini-pro", temperature=0.7)
chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,  # your FAISS retriever
    chain_type="stuff",
    return_source_documents=True
)
